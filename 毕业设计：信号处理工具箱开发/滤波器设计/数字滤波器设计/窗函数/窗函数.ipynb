# %% [markdown]
# ### 矩形窗

# %%
#导入使用的库
import numpy as np
from scipy import signal,fft
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

#定义绘制矩形窗时域图和幅频响应图的函数

def freq_boxcar(N):
    wn = signal.windows.boxcar(N) #矩形窗的wn值
    N0 = 2048;N1 = int(N0/2)
    Ha = np.abs(fft.fft(wn,N0))+1e-10;Ha = Ha/np.max(Ha)
    Ar = 20*np.log10(Ha);freq = np.linspace(0,1,N1)

    #绘制矩形窗
    fig,ax = plt.subplots();ax.stem(wn,basefmt="")
    ax.set_title('%d点矩形窗'%(N));ax.set_xlabel('n');ax.set_ylim([0,1.5])
    plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
    fig.savefig('./win_rec1.png',dpi=500)

    #绘制矩形窗的幅度响应
    fig,ax = plt.subplots();ax.plot(freq,Ar[:N1]);ax.grid()
    ax.set_title('%d点矩形窗的幅度响应'%(N));ax.set_xlabel('k')
    ax.set_xlabel(r'$ \omega / \pi $')
    ax.set_ylabel(r'$ 20log_{10}| H ( \omega ) | $')
    ax.set_xlim([0,1]);ax.set_ylim([-100,1])
    ax.xaxis.set_major_locator(MaxNLocator(11))
    ax.yaxis.set_major_locator(MaxNLocator(11))
    plt.rcParams['axes.unicode_minus'] = False #用来显示负号
    fig.savefig('./win_rec2.png',dpi=500)
    return

N = 51 #矩形窗长度
freq_boxcar(N)

# %% [markdown]
# ### 三角形窗

# %%
#导入使用的库
import numpy as np
from scipy import signal,fft
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator


#定义绘制三角形窗时域图和幅频响应图的函数

def freq_bartlett(N):
    wn = signal.windows.bartlett(N) #三角形窗的wn值
    N0 = 2048;N1 = int(N0/2)
    Ha = np.abs(fft.fft(wn,N0))+1e-10;Ha = Ha/np.max(Ha)
    Ar = 20*np.log10(Ha);freq = np.linspace(0,1,N1)

    #绘制三角形窗
    fig,ax = plt.subplots();ax.stem(wn,basefmt="")
    ax.set_title('%d点三角形窗'%(N))
    ax.set_xlabel('n');ax.set_ylim([0,1.5])
    plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
    fig.savefig('./win_tri1.png',dpi=500)

    #绘制三角形窗的幅度响应
    fig,ax = plt.subplots();ax.plot(freq,Ar[:N1]);ax.grid()
    ax.set_title('%d点三角形窗的幅度响应'%(N));ax.set_xlabel('k')
    ax.set_xlabel(r'$ \omega / \pi $')
    ax.set_ylabel(r'$ 20log_{10}| H ( \omega ) | $')
    ax.set_xlim([0,1]);ax.set_ylim([-100,1])
    ax.xaxis.set_major_locator(MaxNLocator(11))
    ax.yaxis.set_major_locator(MaxNLocator(11))
    plt.rcParams['axes.unicode_minus'] = False #用来显示负号
    fig.savefig('./win_tri2.png',dpi=500)
    return 

N = 51 #三角形窗长度
freq_bartlett(N)

# %% [markdown]
# ### 汉宁窗

# %%
#导入使用的库
import numpy as np
from scipy import signal,fft
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator


#定义绘制汉宁窗时域图和幅频响应图的函数
def freq_hann(N):
    wn = signal.windows.hann(N) #汉宁窗的wn值
    N0 = 2048;N1 = int(N0/2)
    Ha = np.abs(fft.fft(wn,N0))+1e-10;Ha = Ha/np.max(Ha)
    Ar = 20*np.log10(Ha);freq = np.linspace(0,1,N1)

    #绘制汉宁窗
    fig,ax = plt.subplots();ax.stem(wn,basefmt="")
    ax.set_title('%d点汉宁窗'%(N))
    ax.set_xlabel('n');ax.set_ylim([0,1.5])
    plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
    fig.savefig('./win_hann1.png',dpi=500)

    #绘制汉宁窗的幅度响应
    fig,ax = plt.subplots();ax.plot(freq,Ar[:N1]);ax.grid()
    ax.set_title('%d点汉宁窗的幅度响应'%(N));ax.set_xlabel('k')
    ax.set_xlabel(r'$ \omega / \pi $')
    ax.set_ylabel(r'$ 20log_{10}| H ( \omega ) | $')
    ax.set_xlim([0,1]);ax.set_ylim([-120,1])
    ax.xaxis.set_major_locator(MaxNLocator(11))
    ax.yaxis.set_major_locator(MaxNLocator(13))
    plt.rcParams['axes.unicode_minus'] = False #用来显示负号
    fig.savefig('./win_hann2.png',dpi=500)
    
    return

N = 51 #汉宁窗长度
freq_hann(N)

# %% [markdown]
# ### 海明窗

# %%
#导入使用的库
import numpy as np
from scipy import signal,fft
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

#定义绘制海明窗时域图和幅频响应图的函数
def freq_hamming(N):
    wn = signal.windows.hamming(N) #海明窗的wn值
    N0 = 2048;N1 = int(N0/2)
    Ha = np.abs(fft.fft(wn,N0))+1e-10;Ha = Ha/np.max(Ha)
    Ar = 20*np.log10(Ha);freq = np.linspace(0,1,N1)

    #绘制海明窗
    fig,ax = plt.subplots();ax.stem(wn,basefmt="")
    ax.set_title('%d点海明窗'%(N))
    ax.set_xlabel('n');ax.set_ylim([0,1.5])
    plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
    fig.savefig('./win_hamming1.png',dpi=500)

    #绘制海明窗的幅度响应
    fig,ax = plt.subplots();ax.plot(freq,Ar[:N1]);ax.grid()
    ax.set_title('%d点海明窗的幅度响应'%(N));ax.set_xlabel('k')
    ax.set_xlabel(r'$ \omega / \pi $')
    ax.set_ylabel(r'$ 20log_{10}| H ( \omega ) | $')
    ax.set_xlim([0,1]);ax.set_ylim([-100,1])
    ax.xaxis.set_major_locator(MaxNLocator(11))
    ax.yaxis.set_major_locator(MaxNLocator(11))
    plt.rcParams['axes.unicode_minus'] = False #用来显示负号
    fig.savefig('./win_hamming2.png',dpi=500)
    return

N = 51 #海明窗长度
freq_hamming(N)

# %% [markdown]
# ### 布莱克曼窗

# %%
#导入使用的库
import numpy as np
from scipy import signal,fft
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

#定义绘制布拉克曼窗时域图和幅频响应图的函数
def freq_blackman(N):
    wn = signal.windows.blackman(N) #布拉克曼窗的wn值
    N0 = 2048;N1 = int(N0/2)
    Ha = np.abs(fft.fft(wn,N0))+1e-10;Ha = Ha/np.max(Ha)
    Ar = 20*np.log10(Ha);freq = np.linspace(0,1,N1)

    #绘制布拉克曼窗
    fig,ax = plt.subplots();ax.stem(wn,basefmt="")
    ax.set_title('%d点布拉克曼窗'%(N))
    ax.set_xlabel('n');ax.set_ylim([0,1.5])
    plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
    fig.savefig('./win_blac1.png',dpi=500)

    #绘制布拉克曼窗的幅度响应
    fig,ax = plt.subplots();ax.plot(freq,Ar[:N1]);ax.grid()
    ax.set_title('%d点布拉克曼窗的幅度响应'%(N));ax.set_xlabel('k')
    ax.set_xlabel(r'$ \omega / \pi $')
    ax.set_ylabel(r'$ 20log_{10}| H ( \omega ) | $')
    ax.set_xlim([0,1]);ax.set_ylim([-150,1])
    ax.xaxis.set_major_locator(MaxNLocator(11))
    ax.yaxis.set_major_locator(MaxNLocator(16))
    plt.rcParams['axes.unicode_minus'] = False #用来显示负号
    fig.savefig('./win_blac2.png',dpi=500)
    
    return

N = 51
freq_blackman(N)

# %% [markdown]
# ### 高斯窗

# %%
#导入使用的库
import numpy as np
from scipy import signal,fft
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

#定义绘制高斯窗时域图和幅频响应图的函数
def freq_gaussian(N):
    wn = signal.windows.gaussian(N,7) #高斯窗的wn值
    N0 = 2048;N1 = int(N0/2)
    Ha = np.abs(fft.fft(wn,N0))+1e-10;Ha = Ha/np.max(Ha)
    Ar = 20*np.log10(Ha);freq = np.linspace(0,1,N1)

    #绘制高斯窗
    fig,ax = plt.subplots();ax.stem(wn,basefmt="")
    ax.set_title('%d点高斯窗(a = 1/7)'%(N))
    ax.set_xlabel('n');ax.set_ylim([0,1.5])
    plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
    fig.savefig('./win_gauss1.png',dpi=500)

    #绘制高斯窗的幅度响应
    fig,ax = plt.subplots();ax.plot(freq,Ar[:N1]);ax.grid()
    ax.set_title('%d点高斯窗的幅度响应(a= 1/7)'%(N));ax.set_xlabel('k')
    ax.set_xlabel(r'$ \omega / \pi $')
    ax.set_ylabel(r'$ 20log_{10}| H ( \omega ) | $')
    ax.set_xlim([0,1]);ax.set_ylim([-100,1])
    ax.xaxis.set_major_locator(MaxNLocator(11))
    ax.yaxis.set_major_locator(MaxNLocator(11))
    plt.rcParams['axes.unicode_minus'] = False #用来显示负号
    fig.savefig('./win_gauss2.png',dpi=500)
    return

N = 51 #高斯窗长度
freq_gaussian(N)

# %% [markdown]
# ### 凯塞尔窗

# %%
#导入使用的库
import numpy as np
from scipy import signal,fft
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

#定义绘制凯塞尔窗时域图和幅频响应图的函数
def freq_kaiser(N):
    wn = signal.windows.kaiser(N,14) #凯塞尔窗的wn值
    N0 = 2048;N1 = int(N0/2)
    Ha = np.abs(fft.fft(wn,N0))+1e-10;Ha = Ha/np.max(Ha)
    Ar = 20*np.log10(Ha);freq = np.linspace(0,1,N1)

    #绘制凯塞尔窗
    fig,ax = plt.subplots();ax.stem(wn,basefmt="")
    ax.set_title('%d点凯塞尔窗(πa = 14)'%(N))
    ax.set_xlabel('n');ax.set_ylim([0,1.5])
    plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
    fig.savefig('./win_kaiser1.png',dpi=500)

    #绘制凯塞尔窗的幅度响应
    fig,ax = plt.subplots();ax.plot(freq,Ar[:N1]);ax.grid()
    ax.set_title('%d点凯塞尔窗的幅度响应(πa = 14)'%(N))
    ax.set_xlabel('k')
    ax.set_xlabel(r'$ \omega / \pi $')
    ax.set_ylabel(r'$ 20log_{10}| H ( \omega ) | $')
    ax.set_xlim([0,1]);ax.set_ylim([-150,1])
    ax.xaxis.set_major_locator(MaxNLocator(11))
    ax.yaxis.set_major_locator(MaxNLocator(16))
    plt.rcParams['axes.unicode_minus'] = False #用来显示负号
    fig.savefig('./win_kaiser2.png',dpi=500)
    return

N = 51 #凯塞尔窗长度
freq_kaiser(N)
