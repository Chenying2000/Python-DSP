# %% [markdown]
# ## 正弦函数sinc和迪利克雷函数Dirichlet

# %% [markdown]
# ### 正弦函数sinc

# %% [markdown]
# sinc 函数计算输入向量或矩阵 x 的数学正弦函数。作为时间或空间的函数，sinc 函数是以零为中心、宽度为 2π 并具有单位高度的频率的矩形脉冲的傅里叶逆变换：![image.png](attachment:image.png)

# %% [markdown]
# 要绘制值范围从 −5 到 5 的线性间距向量的 sinc 函数，请使用以下命令：

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import special
x = np.linspace(-5,5,1000)
y = special.sinc(x)
#Draw the waveform
plt.plot(x, y)

# %% [markdown]
# ### 迪利克雷函数Dlrichlet

# %% [markdown]
# diric 函数计算输入向量或矩阵 x 的 Dirichlet 函数，有时称为周期性正弦函数或混叠正弦函数。Dirichlet 函数由下式定义：![image.png](attachment:image.png)

# %% [markdown]
# 其中 N 是用户指定的正整数。如果 N 为奇数，则 Dirichlet 函数的周期为2π；如果 N 为偶数，则其周期为 4π。此函数的幅值是 1/N 乘以包含 N 个点的矩形窗的离散时间傅里叶变换的幅值。

# %% [markdown]
# 目的：要为 N=7 和 N=8 绘制 0 和 4π 之间的 Dirichlet 函数

# %%
import numpy as np
from scipy import special
import matplotlib.pyplot as plt
x = np.linspace(-4*np.pi, 4*np.pi, num=201)
plt.figure(figsize=(8, 8));
for idx, n in enumerate([7,8]):
    plt.subplot(2, 1, idx+1)
    plt.plot(x/np.pi, special.diric(x, n))
    plt.title('diric, n={}'.format(n),horizontalalignment='right',x=1.0)
    plt.xlabel('x/pi')
